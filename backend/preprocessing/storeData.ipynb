# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import pandas as pd  
import urllib.parse

# %%
df = pd.read_csv(r"D:\projects\library search engine\backend\preprocessing\books_train.csv" , encoding='utf-8')

# %%
# This safely handles special characters in your password
password = urllib.parse.quote_plus("2005@BengaliSwim")

# Now use the variable in the string
engine = create_engine(f'postgresql://postgres:{password}@localhost:5433/books')

# %%
try:
    df.to_sql('books', engine, if_exists='replace', index=False)
    print("Success! Data uploaded to pgAdmin.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Data uploaded to pgAdmin.

# %%
df.iloc[12]["author"]
# Out:
# 'A.S. King'
